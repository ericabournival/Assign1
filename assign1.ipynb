# %% [markdown]
# **420-SF2-RE: DS & OOP**
#
# **February 12, 2025**

# %% [markdown]
# # Assignment #1: drag with coffee filters
#
# For this assignment you will be allowed to use everything that has been covered in class regarding data science libraries.  **Any functions not covered in class will not be allowed to be used and will receive a grade of 0**.
#
# ${\color{red}\text{You should not be making any direct changes to your .csv files.}}\\$
# ${\color{red}\text{All changes done in this assignment must be done using Python code.}}$

# %% [markdown]
# ## Part 1: experiment with single coffee filter, 10 runs
# **Part 1 DUE DATE: end of class today**
#
# **Part 1 is worth 60% of Assignment #1**
#
# **Part 1 of the assignment is an in-class assignment.  Failure to be in class will receive a grade of 0 for Part 1 of the assignment and late submissions will not be accepted.**
#
#
# #### Submission:
# - Upload all new and updated files to moodle under ${\color{green}\text{Assignment \#1}}$
# - `add`, `commit`, `push` all new and updated files to ${\color{green}\text{git}}$ in your **Assignment #1** folder
# - Late submissions of Part 1 (that is, submissions outside of class) will receive a ${\color{red}\text{late penalty}}$. Part 1 may not be submitted later than **Wendesday, February 12 ay 23:59**.
#
# #### Instructions for Part 1:

# %% [markdown]
# 1. Import all necessary libraries, such as `pandas`, `matplotlib.pyplot`, `numpy`, etc.

# %%
# your code for step 1 goes here:
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# 2. Read  your `.csv` file that has the data of the single filter experiment into a DataFrame called `df`
# 3. Display the content of the data frame to the screen

# %%
# your code for steps 2 and 3 go here:
df = pd.read_csv("Capstone_Data_One_filter.csv")
df
# Out:
#     Time (s) Run #1  Position (m) Run #1  Velocity (m/s) Run #1  \
# 0              0.00                 0.76                    NaN
# 1              0.02                 0.76                   0.02
# 2              0.04                 0.76                   0.02
# 3              0.06                 0.76                   0.02
# 4              0.08                 0.76                   0.01
# ..              ...                  ...                    ...
# 86              NaN                  NaN                    NaN
# 87              NaN                  NaN                    NaN
# 88              NaN                  NaN                    NaN
# 89              NaN                  NaN                    NaN
# 90              NaN                  NaN                    NaN
#
#     Acceleration (m/s²) Run #1  Time (s) Run #2  Position (m) Run #2  \
# 0                          NaN             0.00                 0.72
# 1                          NaN             0.02                 0.72
# 2                         0.06             0.04                 0.72
# 3                        -0.12             0.06                 0.72
# 4                        -0.21             0.08                 0.72
# ..                         ...              ...                  ...
# 86                         NaN              NaN                  NaN
# 87                         NaN              NaN                  NaN
# 88                         NaN              NaN                  NaN
# 89                         NaN              NaN                  NaN
# 90                         NaN              NaN                  NaN
#
#     Velocity (m/s) Run #2  Acceleration (m/s²) Run #2  Time (s) Run #3  \
# 0                     NaN                         NaN             0.00
# 1                   -0.02                         NaN             0.02
# 2                   -0.01                        0.32             0.04
# 3                   -0.01                        0.10             0.06
# 4                   -0.01                       -0.04             0.08
# ..                    ...                         ...              ...
# 86                    NaN                         NaN              NaN
# 87                    NaN                         NaN              NaN
# 88                    NaN                         NaN              NaN
# 89                    NaN                         NaN              NaN
# 90                    NaN                         NaN              NaN
#
#     Position (m) Run #3  ...  Velocity (m/s) Run #8  \
# 0                  0.65  ...                    NaN
# 1                  0.65  ...                   0.05
# 2                  0.65  ...                   0.00
# 3                  0.65  ...                  -0.03
# 4                  0.65  ...                  -0.03
# ..                  ...  ...                    ...
# 86                  NaN  ...                    NaN
# 87                  NaN  ...                    NaN
# 88                  NaN  ...                    NaN
# 89                  NaN  ...                    NaN
# 90                  NaN  ...                    NaN
#
#     Acceleration (m/s²) Run #8  Time (s) Run #9  Position (m) Run #9  \
# 0                          NaN             0.00                 0.68
# 1                          NaN             0.02                 0.68
# 2                        -1.90             0.04                 0.68
# 3                        -0.74             0.06                 0.68
# 4                         0.07             0.08                 0.68
# ..                         ...              ...                  ...
# 86                         NaN              NaN                  NaN
# 87                         NaN              NaN                  NaN
# 88                         NaN              NaN                  NaN
# 89                         NaN              NaN                  NaN
# 90                         NaN              NaN                  NaN
#
#     Velocity (m/s) Run #9  Acceleration (m/s²) Run #9  Time (s) Run #10  \
# 0                     NaN                         NaN              0.00
# 1                   -0.01                         NaN              0.02
# 2                    0.00                        0.20              0.04
# 3                    0.00                        0.05              0.06
# 4                    0.00                       -0.05              0.08
# ..                    ...                         ...               ...
# 86                    NaN                         NaN               NaN
# 87                    NaN                         NaN               NaN
# 88                    NaN                         NaN               NaN
# 89                    NaN                         NaN               NaN
# 90                    NaN                         NaN               NaN
#
#     Position (m) Run #10  Velocity (m/s) Run #10  Acceleration (m/s²) Run #10
# 0                   0.72                     NaN                          NaN
# 1                   0.72                   -0.08                          NaN
# 2                   0.71                   -0.17                        -2.45
# 3                   0.71                   -0.18                         1.75
# 4                   0.71                   -0.06                         3.82
# ..                   ...                     ...                          ...
# 86                   NaN                     NaN                          NaN
# 87                   NaN                     NaN                          NaN
# 88                   NaN                     NaN                          NaN
# 89                   NaN                     NaN                          NaN
# 90                   NaN                     NaN                          NaN
#
# [91 rows x 40 columns]

# %% [markdown]
# 4. Extract from the DataFrame `df` into a new DataFrame `data_df` only the **Time** and **Position** columns for the 10 runs.  Here are the details of how your `data_df` should look:
# - Time column titles should read: **Time (s) Run #$i$** for $0\leq i\leq 10$
# - Position column titles should read: **Position (m) Run #$i$** for $0\leq i\leq 10$
# - The order of the columns in your `data_df` should first display all the **Time** columns then all the **Position** columns.
# - all NaN values should be dropped from `data_df`
# Note that this process should be automated.  You **should not** manually adjust the content of the `data_df` for each run.
# 5. Display the content of `data_df`

# %%
# Your code for steps 4 and 5 go here:
time = []
pos = []
for i in range(1,11):
    time.append(f'Time (s) Run #{i}')

for i in range(1,11):
    pos.append(f'Position (m) Run #{i}')

data_df = df[time+pos]
data_df.fillna(0)
# Out:
#     Time (s) Run #1  Time (s) Run #2  Time (s) Run #3  Time (s) Run #4  \
# 0              0.00             0.00             0.00             0.00
# 1              0.02             0.02             0.02             0.02
# 2              0.04             0.04             0.04             0.04
# 3              0.06             0.06             0.06             0.06
# 4              0.08             0.08             0.08             0.08
# ..              ...              ...              ...              ...
# 86             0.00             0.00             0.00             1.72
# 87             0.00             0.00             0.00             1.74
# 88             0.00             0.00             0.00             1.76
# 89             0.00             0.00             0.00             1.78
# 90             0.00             0.00             0.00             1.80
#
#     Time (s) Run #5  Time (s) Run #6  Time (s) Run #7  Time (s) Run #8  \
# 0              0.00             0.00             0.00             0.00
# 1              0.02             0.02             0.02             0.02
# 2              0.04             0.04             0.04             0.04
# 3              0.06             0.06             0.06             0.06
# 4              0.08             0.08             0.08             0.08
# ..              ...              ...              ...              ...
# 86             1.72             0.00             0.00             1.72
# 87             1.74             0.00             0.00             0.00
# 88             1.76             0.00             0.00             0.00
# 89             0.00             0.00             0.00             0.00
# 90             0.00             0.00             0.00             0.00
#
#     Time (s) Run #9  Time (s) Run #10  Position (m) Run #1  \
# 0              0.00              0.00                 0.76
# 1              0.02              0.02                 0.76
# 2              0.04              0.04                 0.76
# 3              0.06              0.06                 0.76
# 4              0.08              0.08                 0.76
# ..              ...               ...                  ...
# 86             0.00              0.00                 0.00
# 87             0.00              0.00                 0.00
# 88             0.00              0.00                 0.00
# 89             0.00              0.00                 0.00
# 90             0.00              0.00                 0.00
#
#     Position (m) Run #2  Position (m) Run #3  Position (m) Run #4  \
# 0                  0.72                 0.65                 0.72
# 1                  0.72                 0.65                 0.71
# 2                  0.72                 0.65                 0.71
# 3                  0.72                 0.65                 0.71
# 4                  0.72                 0.65                 0.71
# ..                  ...                  ...                  ...
# 86                 0.00                 0.00                 0.86
# 87                 0.00                 0.00                 0.88
# 88                 0.00                 0.00                 0.91
# 89                 0.00                 0.00                 0.90
# 90                 0.00                 0.00                 0.88
#
#     Position (m) Run #5  Position (m) Run #6  Position (m) Run #7  \
# 0                  0.73                 0.71                 0.70
# 1                  0.73                 0.72                 0.70
# 2                  0.73                 0.71                 0.70
# 3                  0.73                 0.71                 0.71
# 4                  0.73                 0.71                 0.71
# ..                  ...                  ...                  ...
# 86                 1.32                 0.00                 0.00
# 87                 1.33                 0.00                 0.00
# 88                 1.32                 0.00                 0.00
# 89                 0.00                 0.00                 0.00
# 90                 0.00                 0.00                 0.00
#
#     Position (m) Run #8  Position (m) Run #9  Position (m) Run #10
# 0                  0.75                 0.68                  0.72
# 1                  0.75                 0.68                  0.72
# 2                  0.75                 0.68                  0.71
# 3                  0.75                 0.68                  0.71
# 4                  0.75                 0.68                  0.71
# ..                  ...                  ...                   ...
# 86                 1.24                 0.00                  0.00
# 87                 0.00                 0.00                  0.00
# 88                 0.00                 0.00                  0.00
# 89                 0.00                 0.00                  0.00
# 90                 0.00                 0.00                  0.00
#
# [91 rows x 20 columns]

# %% [markdown]
# 6. The data in `data_df` contains noisy data.  In this step you are to clean the noisy data (or extract the clean data). Your cleaned data **for each run**
# - must not include the data that is after once the filter hits the motion sensor
# - must include the curved data that transitions into a drop in position.  You should only keep about 0.5 to 1 second of the roughly constant position values before the drop of position takes place.
# Note that you should clean your data for each of the 10 runs and you should automate this process in your code with logical conditions, loops, etc.
#
# 7. Store your clean data into a new DataFrame called `clean_df`.
# 8. Note that now that the values in the **Time** columns may have shifted due to the clean-up.  Update your `clean_df` to rescale all the **Time** columns to start the time from 0.0 in increments of 0.02.
# 9. Write this to a new .csv file called `"clean_data_single_filter.csv"`.

# %%
headers = data_df.columns
cleaned_columns = []
cleaned_df = []

min_start = float('inf')
max_end = float('-inf')

# 1st pass, find relevant data. Keep column sizes.
position_headers = [header for header in headers if "Position" in header]
for header in position_headers:

    col= df[header]
    start = col[0]
    ptr = 0

    # Keep going until we start going down far enough from the start point
    while (start - col[ptr]) < 0.01:
        ptr += 1
    real_start = ptr 

    # Keep going until we get a big spike up.
    while (col[ptr] - col[ptr-1]) < 0.3:
        ptr += 1
    real_end = ptr -1

    # Go back to trim duplicates off the start
    ptr = real_start
    while col[real_start] == col[ptr]:
        ptr += 1
    real_start = ptr - 1 #ptr-1 is the last duplicate of real_start

    # Go back to trim duplicates off the end
    ptr = real_end
    while col[real_end] == col[ptr]:
        ptr -= 1
    real_end = ptr + 1 # ptr+1 is the last duplicate of real_end

    # Clear everything else.
    for i in range(0, real_start):
        col[i] = None
    for i in range(real_end + 1, col.size):  # +1 because lb is inclusive
        col[i] = None

    # Update the global markers to determine the column with the biggest size
    min_start = min(real_start, min_start)
    max_end = max(real_end, max_end)

    cleaned_columns.append(col)

# 2nd pass. Trim cleaned columns based on the sizes we found on the first pass.
for col in cleaned_columns:
    col = col[min_start:max_end]
    cleaned_df.append(col)

pd.DataFrame(cleaned_df).transpose().to_csv("clean_data_single_filter.csv", index=False)

# %% [markdown]
# 10. Plot the data using `matplotlib` from all 10 runs as scatter plots on the same figure using your cleaned data.
# - Each plot should have a label **Run #$i$** for $1\leq i\leq10$
# - The label on the x-axis should read **Time (s)**
# - The label on the y-axis should read **Position (m)**
# - Each plot should be in a different color and there should be a legend showing which colour is which run.
# - scale the size of the points so that they are not too big.
# Note that you should automate the process of plotting the 10 graphs.
#
# 11. Take the last 0.5 to 1 second of the x-values in your 10 runs, and draw a line of best fit on all your 10 graphs.

# %%
for col in cleaned_df:
    ypoints = pd.DataFrame(col.values).to_numpy()
    xpoints = pd.DataFrame([val * 0.02] for val in range(min_start, max_end)).to_numpy()
    plt.xlabel('Time')
    plt.ylabel('Position')
    plt.scatter(xpoints, ypoints, s = 8)
    plt.legend(position_headers)

# %% [markdown]
# ### ${\color{green} \text{Submit your work to moodle and git for Part 1 before moving to Part 2}}$

# %% [markdown]
# ## Part 2: experiment with multiple coffee filters, 10 runs
# **Part 2 DUE DATE: Friday, February 14 at 20:00**
#
# **Part 2 is worth 40% of Assignment #1**
#
# #### Submission:
# - Upload all new and updated files to moodle under ${\color{green}\text{Assignment \#1}}$.  Make sure to not delete or overwrite any files during your previous submissions.
# - `add`, `commit`, `push` all new and updated files to ${\color{green}\text{git}}$ in your **Assignment #1** folder
# - late submissions of Part 2 will receive a grade of 0.
#
#
# #### Instructions for Part 2:

# %% [markdown]
# 1. Read  your .csv file that has the data of filters of varying mass into a DataFrame `df`.
# 3. Display the content of the DataFrame to the screen

# %%
# Your code for steps 1 and 2 go here:
df = pd.read_csv('Capstone_Data.csv')
df
# Out:
#     Time (s) Run #1  Position (m) Run #1  Velocity (m/s) Run #1  \
# 0              0.00                 1.01                    NaN
# 1              0.02                 1.03                  -2.24
# 2              0.04                 0.93                  -1.60
# 3              0.06                 0.92                  -0.86
# 4              0.08                 0.93                   0.03
# ..              ...                  ...                    ...
# 80              NaN                  NaN                    NaN
# 81              NaN                  NaN                    NaN
# 82              NaN                  NaN                    NaN
# 83              NaN                  NaN                    NaN
# 84              NaN                  NaN                    NaN
#
#     Acceleration (m/s²) Run #1  Time (s) Run #2  Position (m) Run #2  \
# 0                          NaN             0.00                 0.76
# 1                          NaN             0.02                 0.76
# 2                        34.50             0.04                 0.76
# 3                        32.39             0.06                 0.76
# 4                        20.88             0.08                 0.76
# ..                         ...              ...                  ...
# 80                         NaN             1.60                 0.92
# 81                         NaN             1.62                 0.92
# 82                         NaN             1.64                 0.91
# 83                         NaN             1.66                 1.12
# 84                         NaN             1.68                 0.88
#
#     Velocity (m/s) Run #2  Acceleration (m/s²) Run #2  Time (s) Run #3  \
# 0                     NaN                         NaN             0.00
# 1                    0.06                         NaN             0.02
# 2                    0.04                       -1.14             0.04
# 3                    0.02                       -1.52             0.06
# 4                   -0.03                       -1.44             0.08
# ..                    ...                         ...              ...
# 80                   0.18                       18.70              NaN
# 81                   1.77                        0.84              NaN
# 82                   1.36                         NaN              NaN
# 83                  -0.66                         NaN              NaN
# 84                    NaN                         NaN              NaN
#
#     Position (m) Run #3  ...  Velocity (m/s) Run #8  \
# 0                  0.99  ...                    NaN
# 1                  1.00  ...                  -0.04
# 2                  1.00  ...                   0.08
# 3                  1.00  ...                  -0.01
# 4                  1.00  ...                  -0.21
# ..                  ...  ...                    ...
# 80                  NaN  ...                    NaN
# 81                  NaN  ...                    NaN
# 82                  NaN  ...                    NaN
# 83                  NaN  ...                    NaN
# 84                  NaN  ...                    NaN
#
#     Acceleration (m/s²) Run #8  Time (s) Run #9  Position (m) Run #9  \
# 0                          NaN             0.00                 0.98
# 1                          NaN             0.02                 0.98
# 2                         0.66             0.04                 0.94
# 3                        -5.40             0.06                 0.94
# 4                        -8.02             0.08                 0.94
# ..                         ...              ...                  ...
# 80                         NaN              NaN                  NaN
# 81                         NaN              NaN                  NaN
# 82                         NaN              NaN                  NaN
# 83                         NaN              NaN                  NaN
# 84                         NaN              NaN                  NaN
#
#     Velocity (m/s) Run #9  Acceleration (m/s²) Run #9  Time (s) Run #10  \
# 0                     NaN                         NaN              0.00
# 1                   -0.82                         NaN              0.02
# 2                   -0.62                       12.65              0.04
# 3                   -0.32                       13.38              0.06
# 4                    0.01                       10.24              0.08
# ..                    ...                         ...               ...
# 80                    NaN                         NaN              1.60
# 81                    NaN                         NaN              1.62
# 82                    NaN                         NaN              1.64
# 83                    NaN                         NaN              1.66
# 84                    NaN                         NaN               NaN
#
#     Position (m) Run #10  Velocity (m/s) Run #10  Acceleration (m/s²) Run #10
# 0                   0.91                     NaN                          NaN
# 1                   0.91                   -0.10                          NaN
# 2                   0.91                   -0.03                         2.03
# 3                   0.91                   -0.01                         0.34
# 4                   0.91                   -0.03                        -0.28
# ..                   ...                     ...                          ...
# 80                  0.88                   -0.83                         0.81
# 81                  0.87                   -0.49                          NaN
# 82                  0.90                    0.27                          NaN
# 83                  0.88                     NaN                          NaN
# 84                   NaN                     NaN                          NaN
#
# [85 rows x 40 columns]

# %% [markdown]
# 3. Extract from the DataFrame `df` into a new DataFrame `data_df` only the **Time** and **Position** columns for the 10 runs.  Here are the details of how your `data_df` should look:
# - Time column titles should read: **Time (s) Run #$i$** for $0\leq i\leq 10$
# - Position column titles should read: **Position (m) Run #$i$** for $0\leq i\leq 10$
# - The order of the columns in your `data_df` should first display all the **Time** columns then all the **Position** columns.
# - all NaN values should be dropped from `data_df`
# Note that this process should be automated.
# 4. Display the content of `data_df`

# %%
# Your code for steps 3 and 4 go here:
time = []
pos = []
for i in range(1,11):
    time.append(f'Time (s) Run #{i}')

for i in range(1,11):
    pos.append(f'Position (m) Run #{i}')

data_df = df[time+pos]
data_df.fillna(0)
# Out:
#     Time (s) Run #1  Time (s) Run #2  Time (s) Run #3  Time (s) Run #4  \
# 0              0.00             0.00             0.00             0.00
# 1              0.02             0.02             0.02             0.02
# 2              0.04             0.04             0.04             0.04
# 3              0.06             0.06             0.06             0.06
# 4              0.08             0.08             0.08             0.08
# ..              ...              ...              ...              ...
# 80             0.00             1.60             0.00             0.00
# 81             0.00             1.62             0.00             0.00
# 82             0.00             1.64             0.00             0.00
# 83             0.00             1.66             0.00             0.00
# 84             0.00             1.68             0.00             0.00
#
#     Time (s) Run #5  Time (s) Run #6  Time (s) Run #7  Time (s) Run #8  \
# 0              0.00             0.00             0.00             0.00
# 1              0.02             0.02             0.02             0.02
# 2              0.04             0.04             0.04             0.04
# 3              0.06             0.06             0.06             0.06
# 4              0.08             0.08             0.08             0.08
# ..              ...              ...              ...              ...
# 80             0.00             0.00             0.00             0.00
# 81             0.00             0.00             0.00             0.00
# 82             0.00             0.00             0.00             0.00
# 83             0.00             0.00             0.00             0.00
# 84             0.00             0.00             0.00             0.00
#
#     Time (s) Run #9  Time (s) Run #10  Position (m) Run #1  \
# 0              0.00              0.00                 1.01
# 1              0.02              0.02                 1.03
# 2              0.04              0.04                 0.93
# 3              0.06              0.06                 0.92
# 4              0.08              0.08                 0.93
# ..              ...               ...                  ...
# 80             0.00              1.60                 0.00
# 81             0.00              1.62                 0.00
# 82             0.00              1.64                 0.00
# 83             0.00              1.66                 0.00
# 84             0.00              0.00                 0.00
#
#     Position (m) Run #2  Position (m) Run #3  Position (m) Run #4  \
# 0                  0.76                 0.99                 1.02
# 1                  0.76                 1.00                 0.88
# 2                  0.76                 1.00                 0.87
# 3                  0.76                 1.00                 0.87
# 4                  0.76                 1.00                 0.88
# ..                  ...                  ...                  ...
# 80                 0.92                 0.00                 0.00
# 81                 0.92                 0.00                 0.00
# 82                 0.91                 0.00                 0.00
# 83                 1.12                 0.00                 0.00
# 84                 0.88                 0.00                 0.00
#
#     Position (m) Run #5  Position (m) Run #6  Position (m) Run #7  \
# 0                  1.02                 1.03                 0.96
# 1                  1.02                 1.05                 0.97
# 2                  1.02                 0.90                 0.93
# 3                  1.02                 0.89                 0.93
# 4                  1.02                 0.90                 0.93
# ..                  ...                  ...                  ...
# 80                 0.00                 0.00                 0.00
# 81                 0.00                 0.00                 0.00
# 82                 0.00                 0.00                 0.00
# 83                 0.00                 0.00                 0.00
# 84                 0.00                 0.00                 0.00
#
#     Position (m) Run #8  Position (m) Run #9  Position (m) Run #10
# 0                  1.00                 0.98                  0.91
# 1                  1.00                 0.98                  0.91
# 2                  1.00                 0.94                  0.91
# 3                  1.01                 0.94                  0.91
# 4                  1.01                 0.94                  0.91
# ..                  ...                  ...                   ...
# 80                 0.00                 0.00                  0.88
# 81                 0.00                 0.00                  0.87
# 82                 0.00                 0.00                  0.90
# 83                 0.00                 0.00                  0.88
# 84                 0.00                 0.00                  0.00
#
# [85 rows x 20 columns]

# %% [markdown]
# 5. The data in `data_df` contains noisy data.  In this step you are to clean the noisy data (or extract the clean data). Your cleaned data **for each run**
# - must not include the data that is after once the filter hits the motion sensor
# - must include only the bit where a drop in position starts.  You should not include any constant position values before the drop of positions takes place.
# Note that you should clean your data for each of the 10 runs and you should automate this process in your code with logical conditions, loops, etc.
# 6. Store your clean data into a new DataFrame called `clean_df`.
# 7. Note that now that the values in the **Time** columns may have shifted due to the clean-up.  Update your `clean_df` to rescale all the **Time** columns to start the time from 0.0 in increments of 0.02.
# 8. Write this to a new .csv file called `"clean_data_multiple_filter.csv"`.

# %%
# Your code for steps 5-8 go here:
headers = data_df.columns
cleaned_columns = []
cleaned_df = []

min_start = float('inf')
max_end = float('-inf')

# 1st pass, find relevant data. Keep column sizes.
position_headers = [header for header in headers if "Position" in header]
for header in position_headers:

    col= df[header]
    start = col[0]
    ptr = 0

    # Keep going until we start going down far enough from the start point
    while (start - col[ptr]) < 0.01:
        ptr += 1
    real_start = ptr 

    # Keep going until we get a big spike up.
    while (col[ptr] - col[ptr-1]) < 0.3:
        ptr += 1
    real_end = ptr -1

    # Go back to trim duplicates off the start
    ptr = real_start
    while col[real_start] == col[ptr]:
        ptr += 1
    real_start = ptr - 1 #ptr-1 is the last duplicate of real_start

    # Go back to trim duplicates off the end
    ptr = real_end
    while col[real_end] == col[ptr]:
        ptr -= 1
    real_end = ptr + 1 # ptr+1 is the last duplicate of real_end

    # Clear everything else.
    for i in range(0, real_start):
        col[i] = None
    for i in range(real_end + 1, col.size):  # +1 because lb is inclusive
        col[i] = None

    # Update the global markers to determine the column with the biggest size
    min_start = min(real_start, min_start)
    max_end = max(real_end, max_end)

    cleaned_columns.append(col)

# 2nd pass. Trim cleaned columns based on the sizes we found on the first pass.
for col in cleaned_columns:
    col = col[min_start:max_end]
    cleaned_df.append(col)

pd.DataFrame(cleaned_df).transpose().to_csv("clean_data_multiple_filter.csv", index=False)

# %% [markdown]
# 9. Plot the data from all 10 runs as line plots on the same figure using your cleaned data.
# - Each plot should have a label **Run #$i$** for $1\leq i\leq10$
# - The label on the x-axis should read **Time (s)**
# - The label on the y-axis should read **Position (m)**
# - Each plot should be in a different color and there should be a legend showing which colour is which run.

# %%
# Your code for step 9 goes here:
for col in cleaned_df:
    ypoints = pd.DataFrame(col.values).to_numpy()
    xpoints = pd.DataFrame([val * 0.02] for val in range(min_start, max_end)).to_numpy()

    plt.xlabel('Time')
    plt.ylabel('Position')
    plt.scatter(xpoints, ypoints, s = 8)
    plt.legend(position_headers)
